# %%
# %pip install -q jupysql "psycopg[binary]"
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext sql

# %sql postgresql+psycopg://postgres:hale310707@db.ygwrwqpyhkizhalsfgut.supabase.co:5432/postgres?sslmode=require
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# Connecting to 'postgresql+psycopg://postgres:***@db.ygwrwqpyhkizhalsfgut.supabase.co:5432/postgres?sslmode=require'

# %%
# %%sql
# SELECT table_schema, table_name
# FROM information_schema.tables
# WHERE table_schema NOT IN ('pg_catalog','information_schema')
# ORDER BY table_schema, table_name;
# Out:
# Running query in 'postgresql+psycopg://postgres:***@db.ygwrwqpyhkizhalsfgut.supabase.co:5432/postgres?sslmode=require'
# 31 rows affected.
# +--------------+-------------------+
# | table_schema |     table_name    |
# +--------------+-------------------+
# |     auth     | audit_log_entries |
# |     auth     |     flow_state    |
# |     auth     |     identities    |
# |     auth     |     instances     |
# |     auth     |   mfa_amr_claims  |
# |     auth     |   mfa_challenges  |
# |     auth     |    mfa_factors    |
# |     auth     |   oauth_clients   |
# |     auth     |  one_time_tokens  |
# |     auth     |   refresh_tokens  |
# +--------------+-------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT table_schema, table_name
# FROM information_schema.tables
# WHERE table_schema NOT IN ('pg_catalog','information_schema')
# ORDER BY table_schema, table_name;
# Out:
# Running query in 'postgresql+psycopg://postgres:***@db.ygwrwqpyhkizhalsfgut.supabase.co:5432/postgres?sslmode=require'
# 31 rows affected.
# +--------------+-------------------+
# | table_schema |     table_name    |
# +--------------+-------------------+
# |     auth     | audit_log_entries |
# |     auth     |     flow_state    |
# |     auth     |     identities    |
# |     auth     |     instances     |
# |     auth     |   mfa_amr_claims  |
# |     auth     |   mfa_challenges  |
# |     auth     |    mfa_factors    |
# |     auth     |   oauth_clients   |
# |     auth     |  one_time_tokens  |
# |     auth     |   refresh_tokens  |
# +--------------+-------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT table_schema, table_name
# FROM information_schema.tables
# WHERE table_schema = 'public'
# ORDER BY table_name;
# Out:
# Running query in 'postgresql+psycopg://postgres:***@db.ygwrwqpyhkizhalsfgut.supabase.co:5432/postgres?sslmode=require'
# 2 rows affected.
# +--------------+------------+
# | table_schema | table_name |
# +--------------+------------+
# |    public    | inquiries  |
# |    public    |  listings  |
# +--------------+------------+

# %%
# %%sql
# SELECT *
# FROM public.listings
# LIMIT 5;
# Out:
# Running query in 'postgresql+psycopg://postgres:***@db.ygwrwqpyhkizhalsfgut.supabase.co:5432/postgres?sslmode=require'
# 5 rows affected.
# ...

# %%
# %%sql
# SELECT column_name, data_type
# FROM information_schema.columns
# WHERE table_schema='public' AND table_name='listings'
# ORDER BY ordinal_position;
# Out:
# Running query in 'postgresql+psycopg://postgres:***@db.ygwrwqpyhkizhalsfgut.supabase.co:5432/postgres?sslmode=require'
# 20 rows affected.
# +----------------+-------------------+
# |  column_name   |     data_type     |
# +----------------+-------------------+
# |       id       | character varying |
# | property_name  | character varying |
# | address_line1  | character varying |
# |      city      | character varying |
# |     state      | character varying |
# |    zip_code    | character varying |
# |     price      |  double precision |
# |    bedrooms    |  double precision |
# |   bathrooms    |  double precision |
# | square_footage |      integer      |
# +----------------+-------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT column_name, data_type
# FROM information_schema.columns
# WHERE table_schema='public' AND table_name='listings'
# ORDER BY ordinal_position;
# Out:
# Running query in 'postgresql+psycopg://postgres:***@db.ygwrwqpyhkizhalsfgut.supabase.co:5432/postgres?sslmode=require'
# 20 rows affected.
# +----------------+-------------------+
# |  column_name   |     data_type     |
# +----------------+-------------------+
# |       id       | character varying |
# | property_name  | character varying |
# | address_line1  | character varying |
# |      city      | character varying |
# |     state      | character varying |
# |    zip_code    | character varying |
# |     price      |  double precision |
# |    bedrooms    |  double precision |
# |   bathrooms    |  double precision |
# | square_footage |      integer      |
# +----------------+-------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT *
# FROM public.listings
# LIMIT 10;
# Out:
# Running query in 'postgresql+psycopg://postgres:***@db.ygwrwqpyhkizhalsfgut.supabase.co:5432/postgres?sslmode=require'
# 10 rows affected.
# ...

# %%
# %%sql
# SELECT COUNT(*) AS total_listings
# FROM public.listings;
# Out:
# Running query in 'postgresql+psycopg://postgres:***@db.ygwrwqpyhkizhalsfgut.supabase.co:5432/postgres?sslmode=require'
# 1 rows affected.
# +----------------+
# | total_listings |
# +----------------+
# |       49       |
# +----------------+

# %%
# %%sql
# SELECT column_name, data_type
# FROM information_schema.columns
# WHERE table_schema='public' AND table_name='listings'
# ORDER BY ordinal_position;
# Out:
# Running query in 'postgresql+psycopg://postgres:***@db.ygwrwqpyhkizhalsfgut.supabase.co:5432/postgres?sslmode=require'
# 20 rows affected.
# +----------------+-------------------+
# |  column_name   |     data_type     |
# +----------------+-------------------+
# |       id       | character varying |
# | property_name  | character varying |
# | address_line1  | character varying |
# |      city      | character varying |
# |     state      | character varying |
# |    zip_code    | character varying |
# |     price      |  double precision |
# |    bedrooms    |  double precision |
# |   bathrooms    |  double precision |
# | square_footage |      integer      |
# +----------------+-------------------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# SELECT state, COUNT(*) AS num_listings
# FROM public.listings
# GROUP BY state
# ORDER BY num_listings DESC;
# Out:
# Running query in 'postgresql+psycopg://postgres:***@db.ygwrwqpyhkizhalsfgut.supabase.co:5432/postgres?sslmode=require'
# 1 rows affected.
# +-------+--------------+
# | state | num_listings |
# +-------+--------------+
# |   VA  |      49      |
# +-------+--------------+

# %%
# %%sql
# SELECT *
# FROM public.listings
# LIMIT 10;
# Out:
# Running query in 'postgresql+psycopg://postgres:***@db.ygwrwqpyhkizhalsfgut.supabase.co:5432/postgres?sslmode=require'
# 10 rows affected.
# ...

# %%
# remove the wrong h3, if present
# %pip uninstall -y h3 databricks-mosaic

# install Spark + Delta
# %pip install -q pyspark==3.5.1 delta-spark==3.2.0

# install Mosaic with the correct h3
# %pip install -q databricks-mosaic==0.4.0 h3==3.7.0

# (optional) embeddings
# %pip install -q sentence-transformers==2.7.0
# Out:
# WARNING: Skipping h3 as it is not installed.
# WARNING: Skipping databricks-mosaic as it is not installed.
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: Building 'pyspark' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'pyspark'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [2812 lines of output]
# ...
